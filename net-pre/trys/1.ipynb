# %%
print("python nb~")
# Out:
# python nb~

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(*np.random.randn(2, 1000)) # *是参数解包运算

# %% [markdown]
# jupter初体验\
# 正在看【极客时间】的专栏【Python核心技术】

# %%
# 10-12 列表 和 元组
l = [1, 2, 'hello', "world"]
l
# Out:
# [1, 2, 'hello', 'world']

# %%
t = ("renxin", "jimo")
t
# Out:
# ('renxin', 'jimo')

# %%
l = [1, 2, 3, 4]
l[3] = 40
l # 列表是可变的
# Out:
# [1, 2, 3, 40]

# %%
t = (1, 2, 3, 4)
t[3] = 40
t # 元组则不是可变的...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\pre-boofuzz\net-pre\trys\1.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/d%3A/pre-boofuzz/net-pre/trys/1.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> t = (1, 2, 3, 4)
# ----> <a href='vscode-notebook-cell:/d%3A/pre-boofuzz/net-pre/trys/1.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> t[3] = 40
#       <a href='vscode-notebook-cell:/d%3A/pre-boofuzz/net-pre/trys/1.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> t
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup = (1, 2, 3, 4)
new_tup = tup + (5,)
new_tup
# Out:
# (1, 2, 3, 4, 5)

# %%
l = [1, 2, 3, 4]
l.append(5)
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l = [1, 2, 3, 4, 5]
l[-1] # 和其他语言都不同, python支持负数索引
# Out:
# 5

# %%
t = (1, 2, 3, 4, 5)
t[-1]
# Out:
# 5

# %%
l = [1, 2, 3, 4]
l[1:3]
# Out:
# [2, 3]

# %%
t = (1, 2, 3, 4)
t[1:3]
# Out:
# (2, 3)

# %%
# 随意嵌套
l = [[1,2],[3,4]]
l
# Out:
# [[1, 2], [3, 4]]

# %%
t = ((1,2),(3,4))
t
# Out:
# ((1, 2), (3, 4))

# %%
list((1,2,3))
# Out:
# [1, 2, 3]

# %%
tuple([1,2,3])
# Out:
# (1, 2, 3)

# %%
s = "hello"
s[::-1]
# Out:
# 'olleh'
